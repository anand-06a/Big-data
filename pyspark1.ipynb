# %%
import pyspark
import pandas as pd

# %%
df=pd.read_csv('/content/test1.csv')
df.head() #five # if i want 1st 5 data
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000

# %%
# how to check row and column
df.shape
# Out:
# (6, 4)

# %%
df.head(2) # 1st two data
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000

# %%
df.head(5)
# Out:
#        Name  age  Experience  Salary
# 0       Ben   31          10   30000
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000

# %%
df.tail() # last data
# Out:
#        Name  age  Experience  Salary
# 1  Srikanth   30           8   25000
# 2     Sunny   29           4   20000
# 3      Paul   24           3   20000
# 4    Harish   21           1   15000
# 5     Shiva   23           2   18000

# %%
df.tail(2) # last two data
# Out:
#      Name  age  Experience  Salary
# 4  Harish   21           1   15000
# 5   Shiva   23           2   18000

# %%
df.info() # to find the null value # 6 non-null is no null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   age         6 non-null      int64
#  2   Experience  6 non-null      int64
#  3   Salary      6 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 324.0+ bytes

# %%
df.isnull().sum() # to check a null value yes are no # there is zero means no null value
# Out:
# Name          0
# age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Demo').getOrCreate()

# %%
spark

# %%
df=spark.read.csv('/content/test1.csv')
df.show(2)
# Out:
# +----+---+----------+------+
# | _c0|_c1|       _c2|   _c3|
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# | Ben| 31|        10| 30000|
# +----+---+----------+------+
# only showing top 2 rows

# %%
df.show()
# Out:
# +--------+---+----------+------+
# |     _c0|_c1|       _c2|   _c3|
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df=spark.read.option('header','true').csv('test1.csv')

# %%
df.show(3)
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# +--------+---+----------+------+
# only showing top 3 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)

# %%
df.head(5)
# Out:
# [Row(Name='Ben', age='31', Experience='10', Salary='30000'),
#  Row(Name='Srikanth', age='30', Experience='8', Salary='25000'),
#  Row(Name='Sunny', age='29', Experience='4', Salary='20000'),
#  Row(Name='Paul', age='24', Experience='3', Salary='20000'),
#  Row(Name='Harish', age='21', Experience='1', Salary='15000')]

# %%
df=spark.read.csv("/content/test1.csv",header=True,inferSchema=True)

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df.head()
# Out:
# Row(Name='Ben', age=31, Experience=10, Salary=30000)

# %%
# selecting single column
df.select('Name').show()
# Out:
# +--------+
# |    Name|
# +--------+
# |     Ben|
# |Srikanth|
# |   Sunny|
# |    Paul|
# |  Harish|
# |   Shiva|
# +--------+

# %%
df.select('Name').show(2)
# Out:
# +--------+
# |    Name|
# +--------+
# |     Ben|
# |Srikanth|
# +--------+
# only showing top 2 rows

# %%
df.select('Name','Experience').show()
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# |    Paul|         3|
# |  Harish|         1|
# |   Shiva|         2|
# +--------+----------+

# %%
df.filter(df['Name']=='Ben').show()
# Out:
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# +----+---+----------+------+
# | Ben| 31|        10| 30000|
# +----+---+----------+------+

# %%
df.filter(df['Experience']==1).show()
# Out:
# +------+---+----------+------+
# |  Name|age|Experience|Salary|
# +------+---+----------+------+
# |Harish| 21|         1| 15000|
# +------+---+----------+------+

# %%
df.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df.describe().show()
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
ord('B')
# Out:
# 66

# %%
print(ord('S'))
# Out:
# 83

# %%
print(ord('P'))
# Out:
# 80

# %%
print(ord('H'))
# Out:
# 72

# %%
print(ord('u'))
# Out:
# 117

# %%
print(ord('r'))
# Out:
# 114

# %%
print(ord('a'))
# Out:
# 97

# %%
print(ord('h'))
# Out:
# 104
